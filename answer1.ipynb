# %%
import pandas as pd
import numpy as np

# %%
veg=pd.read_csv("main.csv")

# %%
veg.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit
# 0              36   kg
# 1              23   kg
# 2              34   kg
# 3              23   kg
# 4              34   kg

# %%
veg.tail()
# Out:
#      product_code product_description product_group  sales_date  price  \
# 295          1203         butter-0.25         dairy  2021-11-26   11.9
# 296          1203         butter-0.25         dairy  2021-11-27   11.9
# 297          1203         butter-0.25         dairy  2021-11-28   11.9
# 298          1203         butter-0.25         dairy  2021-11-29   11.9
# 299          1203         butter-0.25         dairy  2021-11-30   11.9
#
#      sales_quantity unit
# 295              31  pcs
# 296              29  pcs
# 297              37  pcs
# 298              34  pcs
# 299              36  pcs

# %%
veg[2:]
# Out:
#      product_code product_description product_group  sales_date  price  \
# 2            1001              tomato     vegetable  2021-11-03   2.99
# 3            1001              tomato     vegetable  2021-11-04   2.99
# 4            1001              tomato     vegetable  2021-11-05   2.99
# 5            1001              tomato     vegetable  2021-11-06   2.99
# 6            1001              tomato     vegetable  2021-11-07   2.99
# ..            ...                 ...           ...         ...    ...
# 295          1203         butter-0.25         dairy  2021-11-26  11.90
# 296          1203         butter-0.25         dairy  2021-11-27  11.90
# 297          1203         butter-0.25         dairy  2021-11-28  11.90
# 298          1203         butter-0.25         dairy  2021-11-29  11.90
# 299          1203         butter-0.25         dairy  2021-11-30  11.90
#
#      sales_quantity unit
# 2                34   kg
# 3                23   kg
# 4                34   kg
# ...

# %%
veg.groupby('product_description')['price'].mean()
# Out:
# product_description
# apple           2.077778
# butter-0.25    11.400000
# cucumber        4.532857
# grape           4.400000
# milk-1.5        6.078571
# onion           2.150714
# orange          2.714286
# plum            4.389655
# tomato          3.121034
# yogurt-1        6.693103
# Name: price, dtype: float64

# %%
veg.groupby('product_description')['price'].sum()
# Out:
# product_description
# apple           56.10
# butter-0.25    319.20
# cucumber       126.92
# grape          132.00
# milk-1.5       170.20
# onion           60.22
# orange          76.00
# plum           127.30
# tomato          90.51
# yogurt-1       194.10
# Name: price, dtype: float64

# %%
veg["price_new"] = veg['price'].fillna(
   veg.groupby('product_description')['price'].transform("mean")
)

# %%
veg[veg["price"].isna()].head()
# Out:
#     product_code product_description product_group  sales_date  price  \
# 10          1001              tomato     vegetable  2021-11-11    NaN
# 34          1002            cucumber     vegetable  2021-11-05    NaN
# 37          1002            cucumber     vegetable  2021-11-08    NaN
# 73          1003               onion     vegetable  2021-11-14    NaN
# 74          1003               onion     vegetable  2021-11-15    NaN
#
#     sales_quantity unit  price_new
# 10              20   kg   3.121034
# 34              24   kg   4.532857
# 37              38   kg   4.532857
# 73              39   kg   2.150714
# 74              25   kg   2.150714
